# %%
from pygooglenews import GoogleNews
import pandas as pd
from datetime import datetime

# %%
FETCH_DATA = False # Set to True to fetch new data
FROM = "2024-01-01"
TO = "2025-12-31"
TOPIC = "BUSINESS"

# %%
DAX_top_20 = [
    "DAX",  # DAX 40 Index
    "Deutsche Bundesbank",  # German Central Bank
    "Zinssätze",  # Interest rates
    "Inflation",  # Inflation
    "BIP",  # GDP
    "Wirtschaftswachstum",  # Economic growth
    "Wirtschaftskrise",  # Economic crisis
    "Rezession",  # Recession
    "Wirtschaftserholung",  # Economic recovery
    "Aktienmarkt",  # Stock market
    "Investition",  # Investment
    "Aktien",  # Equities
    "Anleihen",  # Bonds
    "Rendite",  # Yield
    "Deutsche Bank",  # Major German bank
    "Commerzbank",  # Major German bank
    "Siemens",  # Major DAX company
    "Volkswagen",  # Major DAX company
    "BASF",  # Major DAX company
    "SAP",  # Major DAX company
]

# %%
# Convert the news data to a DataFrame
def convert_to_dataframe(news):
    data = []
    for article in news['entries']:
        try:
            # Try the original format first
            date = datetime.strptime(article['published'], '%a, %d %b %Y %H:%M:%S %Z')
        except ValueError:
            # If that fails, use pd.to_datetime which is more flexible
            date = pd.to_datetime(article['published'])
            # Convert timezone-aware datetime to timezone-naive
            if date.tzinfo is not None:
                date = date.replace(tzinfo=None)
        title = article['title']
        data.append({'date': date, 'title': title})
    return pd.DataFrame(data)


if FETCH_DATA:
    gn = GoogleNews(lang="de", country="DE")
    news = gn.search(
        query=" OR ".join(DAX_top_20),
        from_=FROM,
        to_=TO,
    )
    # Create a DataFrame from the news data
    df = convert_to_dataframe(news)
    df['date'] = pd.to_datetime(df['date'])

    # Set the date as the index
    df.set_index('date', inplace=True)
    df.to_csv(f".././news/news_data_{FROM}_{TO}_DAX.csv")
else:
    # Read the CSV file
    timestamp = datetime.now().strftime("%Y-%m-%d")
    df = pd.read_csv(f".././news/news_data_{FROM}_{TO}_DAX.csv", parse_dates=['date'])
    df.set_index('date', inplace=True)

# %% [markdown]
# # DAX 40 Volatility and News Article Counts Visualization
# This notebook cell creates a modern, visually appealing plot of DAX 40 volatility and daily news article counts for 2023, using a clean and minimal code approach.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib.ticker import MaxNLocator

# Load data
news_df = pd.read_csv(f".././news/news_data_{FROM}_{TO}_DAX.csv", parse_dates=['date'])
news_df['date'] = pd.to_datetime(news_df['date'])
news_daily = news_df.resample('D', on='date').count().reset_index()

# %%
import yfinance
dax40 = yfinance.Ticker("^GDAXI")
dax40_data = dax40.history(start=FROM, end=TO, interval="1d", auto_adjust=True)
dax40_data = dax40_data[["Close"]].copy()
dax40_data["Returns"] = dax40_data["Close"].pct_change()
dax40_data["Volatility"] = dax40_data["Returns"].rolling(window=21).std() * np.sqrt(252)
dax40_data = dax40_data.dropna().reset_index()

# %%
# Merge news and volatility data
# Convert dax40_data['Date'] to timezone-naive datetime to match news_daily['date']
dax40_data['Date'] = dax40_data['Date'].dt.tz_localize(None)
merged = pd.merge(news_daily, dax40_data, left_on='date', right_on='Date', how='inner')

# Smooth volatility for aesthetics
merged['Volatility_Smooth'] = merged['Volatility'].rolling(window=5, min_periods=1, center=True).mean()
merged.rename(columns={'title': 'count',}, inplace=True)
merged.drop(columns=['Date'], inplace=True)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
fig, ax1 = plt.subplots(figsize=(14, 8))

# Volatility line (right y-axis)
ax2 = ax1.twinx()
sns.lineplot(x='date', y='Volatility_Smooth', data=merged, ax=ax2, color='#d7263d', label='DAX 40 Volatility', linewidth=2.5, zorder=2)
ax2.set_ylabel("DAX 40 Volatility", fontsize=15, color='#d7263d', fontweight='bold')
ax2.tick_params(axis='y', labelcolor='#d7263d', labelsize=12)
ax2.yaxis.set_major_locator(MaxNLocator(nbins=8))

# News article counts (left y-axis, as blue scatter)
ax1.scatter(merged['date'], merged['count'], s=merged['count']*40+30, color='#2176ae', alpha=0.7, edgecolor='white', linewidth=1.5, label='News Article Count', zorder=3)
ax1.set_ylabel("News Article Count", fontsize=15, color='#2176ae', fontweight='bold')
ax1.tick_params(axis='y', labelcolor='#2176ae', labelsize=12)
ax1.set_xlabel("Date", fontsize=15, fontweight='bold')

# Annotate article counts
for i, row in merged.iterrows():
    if row['count'] > 0:
        ax1.text(row['date'], row['count']+0.2, str(row['count']), color='#1b2a41', ha='center', va='bottom', fontsize=10, fontweight='bold', alpha=0.8)

# X-axis formatting
ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(DateFormatter('%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=0, ha='center', fontsize=12)

# Title and legend
plt.title("DAX 40 Volatility and News Article Counts (2023)", fontsize=20, fontweight='bold', pad=20)
ax1.legend(loc='upper left', fontsize=13, frameon=True, fancybox=True, borderpad=1)
ax2.legend(loc='upper right', fontsize=13, frameon=True, fancybox=True, borderpad=1)

plt.tight_layout(pad=2)
plt.show()

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("nojedag/xlm-roberta-finetuned-financial-news-sentiment-analysis-european")
model = AutoModelForSequenceClassification.from_pretrained("nojedag/xlm-roberta-finetuned-financial-news-sentiment-analysis-european")

# %%
def infer_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)
    logits = outputs.logits
    probabilities = logits.softmax(dim=1)
    sentiment = probabilities.argmax(dim=1).item()
    return sentiment

# Add a column with the titles of each date
def get_titles(date):
    return news_df[news_df['date'].dt.date == date.date()]['title'].tolist()

# %%
# calculate sentiment for each date
def calculate_sentiment(date):
    titles = get_titles(date)
    if not titles:
        return None
    sentiments = [infer_sentiment(title) for title in titles]
    if len(sentiments) > 1:
        print(f"Date: {date}, Sentiments: {sentiments}, Titles: {titles}")
    return sum(sentiments) / len(sentiments)

# %%
merged['sentiment'] = merged['date'].apply(calculate_sentiment)
merged['sentiment'] = merged['sentiment'].fillna(-1) # Fill NaN values with -1
# Out:
# Date: 2024-04-30 00:00:00, Sentiments: [2, 1], Titles: ['Deutsche Wirtschaft entgeht Rezession - DW', 'Deutsche Wirtschaft verzeichnet Mini-Wachstum - tagesschau.de']
# Date: 2024-07-30 00:00:00, Sentiments: [2, 0, 2, 1], Titles: ['Deutsche Wirtschaft schrumpft im zweiten Quartal - tagesschau.de', 'Die Effekte staatlicher Stützungsmaßnahmen wie der Gaspreisbremse - Deutsche Bundesbank', 'Deutsche Wirtschaft schrumpft: Vier Gründe, warum Deutschland in der Krise bleibt - Institut der deutschen Wirtschaft (IW)', 'Deutsche Aktien: Warum sich der Dax trotz schwacher Konjunktur gut schlägt - Handelsblatt']
# Date: 2025-01-15 00:00:00, Sentiments: [2, 0, 2, 1], Titles: ['Wirtschaft schrumpft: Deutschland im Griff der Rezession - ZDF', 'Aussichten für 2025: Wohin steuert die deutsche Wirtschaft? - tagesschau.de', 'Deutsche Wirtschaft 2024 erneut geschrumpft - tagesschau.de', 'Deutsche Bank Aktie News: Deutsche Bank am Vormittag billiger - Finanzen.net']
# Date: 2025-05-12 00:00:00, Sentiments: [0, 2, 1], Titles: ['Deutsche Aktien 2025 - LYNX Online Broker', 'Marktbericht: Rückgang der US-Inflation treibt Tech-Werte an - tagesschau.de', 'Deutsche Telekom-Aktie: Lohnt sich der Einstieg jetzt? - boerse.de - boerse.de']
# Date: 2025-05-13 00:00:00, Sentiments: [2, 2, 0], Titles: ['Deutsche Anleihen: Weitere Kursverluste Von dpa-AFX - Investing.com Deutsch', 'Deutsche Anleihen: Leichte Kursverluste vor ZEW-Index und US-Preisdaten Von dpa-AFX - Investing.com Deutsch', 'Deutsche Telekom-Aktie: Was kommt auf die Anleger zu? - Finanztrends']
# Date: 2025-05-14 00:00:00, Sentiments: [1, 2, 0, 1, 2, 2, 1], Titles: ['Deutsche Aktien: Diese drei Fonds sind die Favoriten der Commerzbank | Produkte | 14.05.2025 - FONDS professionell', 'Deutsche Anleihen: Leichte Kursverluste Von dpa-AFX - Investing.com Deutsch', 'Deutsche Aktien im Minus; Hapag-Lloyd-Aktien steigen - MarketScreener Deutschland', 'Deutsche Telekom-Aktie: Noch Kraft? - Finanztrends', 'Deutsche Anleihen: Wenig verändert nach jüngsten Kursverlusten - Ariva', 'Aktien Frankfurt Schluss: Dax schwächelt auf hohem Niveau - Cash', 'Aktien-Tipp EON SE-Aktie: Deutsche Bank AG bewertet Anteilsschein in neuer Analyse - finanzen.at']
# Date: 2025-05-15 00:00:00, Sentiments: [1, 1, 0, 2, 2], Titles: ['Neue Dax-Indizes vorgestellt - das investment', 'Deutsche Börse-Aktie: Champions-Check im Monat Mai - boerse.de - boerse.de', '1. Quartal 2025: Diese US-Aktien hat die Deutsche Bank im Portfolio - Finanzen.net', 'Deutsche Anleihen: Gewinne nach jüngster Schwäche Von dpa-AFX - Investing.com Deutsch', 'Deutsche Aktien legen zu; Merck KGaA fällt aufgrund gesenkter Prognosen - MarketScreener Deutschland']
# Date: 2025-05-16 00:00:00, Sentiments: [2, 1, 2, 2], Titles: ['Deutsche Anleihen: Kursgewinne zum Wochenschluss - US-Daten bremsen etwas Von dpa-AFX - Investing.com Deutsch', 'Deutsche Aktien beenden geschäftige Handelswoche im Plus - MarketScreener Schweiz', 'Deutsche Anleihen: Kursgewinne zum Wochenschluss - US-Daten bremsen etwas - Ariva', 'Deutsche Anleihen: Bund-Future macht Verluste von erster Wochenhälfte fast wett - Ariva']

# %%
label_map = {"negative": 2, "neutral": 0, "positive": 1, "unknown": -1}
sentiment_colors = {2: "#d7263d", 0: "#ffd166", 1: "#06d6a0"}  # Red for negative, yellow for neutral, green for positive
inverse_label_map = {v: k for k, v in label_map.items()}

# Create a figure with two y-axes
fig, ax1 = plt.subplots(figsize=(14, 8))
ax2 = ax1.twinx()  # Create a second y-axis

# Plot volatility line
ax2.plot(merged['date'], merged['Volatility_Smooth'], color='#2176ae', linewidth=2.5, 
         label='DAX 40 Volatility', alpha=0.8)

# Plot sentiment markers on the volatility line
for i, row in merged.iterrows():
    sentiment_value = int(row['sentiment'])
    # Plot sentiment markers directly on the volatility line
    if (sentiment_value > -1) and (sentiment_value < 3):
        # Use the sentiment value to determine the color
        ax2.scatter(row['date'], row['Volatility_Smooth'], 
                    color=sentiment_colors[sentiment_value], 
                    s=100, 
                    zorder=5,
                    edgecolor='white', 
                    linewidth=1.5)

# Add colored marker samples for the legend
for sentiment_value in [0, 1, 2]:
    ax1.scatter([], [], color=sentiment_colors[sentiment_value], 
                label=f"{inverse_label_map[sentiment_value].capitalize()} Sentiment",
                s=100, edgecolor='white', linewidth=1.5)

# Format axes
ax1.set_xlabel("Date", fontsize=15, fontweight='bold')
ax2.set_ylabel("Volatility", fontsize=15, fontweight='bold', color='#2176ae')

# Hide the y-axis on the left since we're not using it for data
ax1.set_yticks([])
ax1.spines['left'].set_visible(False)

# Format date axis
ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=0, ha='center', fontsize=12)

# Add grid for better readability
ax2.grid(axis='y', linestyle='--', alpha=0.3)

# Add title
plt.title("DAX 40 Volatility and News Sentiment", fontsize=20, fontweight='bold', pad=20)

# Create combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=13, frameon=True, fancybox=True)

plt.tight_layout(pad=2)
plt.show()
